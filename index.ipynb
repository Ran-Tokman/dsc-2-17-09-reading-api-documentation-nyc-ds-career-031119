# %% [markdown]
# # Reading API Documentation
#
# The previously deployed lab around working with the twitter API and basic NLP can be found [here](https://github.com/learn-co-curriculum/dsc-2-15-09-accessing-data-from-twitter-lab/tree/3beebcae99f651a1a4c839f8e90120f8403361fb) (not relevant for new students).
#
# ## Introduction
# We've now covered an example API request, but how on Earth would you know how to do that on your own? The answer is through documentation! All APIs will have associated documentation, and while there are substantial similarities, all will be different to one degree or another. The best way to get more comfortable is to practice! So with that, let's take a look at the yelp documentation associated with our previous example.
#
# ## Objectives
#
# You will be able to:
#
# * Read API Documentation
# * Translate documentation into Python code
# * Execute get requests in order to utilize the Yelp API

# %% [markdown]
# Start by navigating to: https://www.yelp.com/developers/documentation/v3/get_started and having a look for yourself!
#
# <img src="yelp_overview.png">

# %% [markdown]
# As you see at the top, the first piece of almost every API is authentication.
#
# This is where we started in the previous codealong, where we went to https://www.yelp.com/developers/v3/manage_app and created a new app.
#
# <img src="yelp_app.png">

# %% [markdown]
# Let's take a closer look at Yelp's authentication documentation:
# https://www.yelp.com/developers/documentation/v3/authentication
#
# <img src="yelp_auth.png">

# %% [markdown]
# Notice in the documentation, it gives us the specific format "Put the API Key in the request header as "Authorization: Bearer <YOUR API KEY>"." This is what we passed in our get request.
#
# As a reminder, we have:

# %%
import requests
import json
client_id = 'hkmQClvOY6h0M9H3Pd1pOg' #Your client ID goes here (as a string)
api_key = 'oJbjVcsSqKLqR2hu4yB8QHllpywC8mAf3TFgFjnyeAQH_9lbkK7vLTKwkMEnnRnVURUbZ4Y37O0csqEthS8Z5Lio79PZ6Mhf-urf1W3aI-CWTtM4Ccn3EGuPumCRXHYx'
#Your api key goes here (as a string)

# %%
url = 'https://api.yelp.com/v3/businesses/search' #This will be our next step
header = {"Authorization" : "Bearer {}".format(api_key)}
response = requests.get(url, header=header)
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-4-908844abe1b9> in <module>()
#       1 url = 'https://api.yelp.com/v3/businesses/search' #This will be our next step
#       2 header = {"Authorization" : "Bearer {}".format(api_key)}
# ----> 3 response = requests.get(url, header=header)
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# TypeError: request() got an unexpected keyword argument 'header'

# %% [markdown]
#  With that, let's take a look at how the rest of our request should be formatted. Go to https://www.yelp.com/developers/documentation/v3/business_search  and take a couple minutes to look things over.
#
#  <img src="yelp_docs.png">

# %% [markdown]
# Notice the first part is the format of the get request! This is the url we pass into our get request. From there, the available parameters that you can pass are listed. These define your query, some are required while others are optional.

# %% [markdown]
# Reviewing our python package we thus have:

# %%
#Note: this cell won't return a valid response unless you specify your api key
url = 'https://api.yelp.com/v3/businesses/search'

headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

url_params = {
                'location': 'NYC'
            }
response = requests.get(url, headers=headers, params=url_params)

# %% [markdown]
# Note that location or latitute and longitude are the only required parameters. That said, you are free to pass as many parameters as you want such as:

# %%
#Note: this cell won't return a valid response unless you specify your api key

url = 'https://api.yelp.com/v3/businesses/search'

headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

url_params = {
                'location': 'NYC',
                'term' : 'pizza',
                'limit' : 50,
                'price' : "1,2,3,4",
                'open_now' : True
            }
response = requests.get(url, headers=headers, params=url_params)
response.json()
# Out:
# {'businesses': [{'id': 'ysqgdbSrezXgVwER2kQWKA',
#    'alias': 'julianas-pizza-brooklyn-5',
#    'name': "Juliana's Pizza",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7JtwTxhWHf3YS70Ss_CfxA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/julianas-pizza-brooklyn-5?adjust_creative=hkmQClvOY6h0M9H3Pd1pOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hkmQClvOY6h0M9H3Pd1pOg',
#    'review_count': 1921,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7026153030093,
#     'longitude': -73.9934159993549},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '19 Old Fulton St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['19 Old Fulton St', 'Brooklyn, NY 11201']},
#    'phone': '+17185966700',
#    'display_phone': '(718) 596-6700',
#    'distance': 323.20506308227306},
#   {'id': 'WIhm0W9197f_rRtDziq5qQ',
#    'alias': 'lombardis-pizza-new-york-4',
#    'name': "Lombardi's Pizza",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UZ6V_hobp1KpYDPOHNoCKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lombardis-pizza-new-york-4?adjust_creative=hkmQClvOY6h0M9H3Pd1pOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hkmQClvOY6h0M9H3Pd1pOg',
#    'review_count': 5796,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72164, 'longitude': -73.9957},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '32 Spring St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['32 Spring St', 'New York, NY 10012']},
#    'phone': '+12129417994',
#    'display_phone': '(212) 941-7994',
#    'distance': 1804.4733931798112},
#   {'id': 'zj8Lq1T8KIC5zwFief15jg',
#    'alias': 'prince-street-pizza-new-york-2',
#    'name': 'Prince Street Pizza',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZAukOyv530w4KjOHC5YY1w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/prince-street-pizza-new-york-2?adjust_creative=hkmQClvOY6h0M9H3Pd1pOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hkmQClvOY6h0M9H3Pd1pOg',
#    'review_count': 2598,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7229087705545,
#     'longitude': -73.9944863319397},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '27 Prince St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['27 Prince St', 'New York, NY 10012']},
#    'phone': '+12129664100',
#    'display_phone': '(212) 966-4100',
#    'distance': 1941.9638172538225},
#   {'id': 'v1DHGRNCH9247WLYoaoA9A',
#    'alias': 'l-industrie-pizzeria-brooklyn',
#    'name': "L'industrie Pizzeria",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SRL_RztRRUijgQwt67daGw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-industrie-pizzeria-brooklyn?adjust_creative=hkmQClvOY6h0M9H3Pd1pOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hkmQClvOY6h0M9H3Pd1pOg',
#    'review_count': 401,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.71162, 'longitude': -73.95783},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '254 S 2nd St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['254 S 2nd St', 'Brooklyn, NY 11211']},
#    'phone': '+17185990002',
#    'display_phone': '(718) 599-0002',
#    'distance': 3145.016041338447},
#   {'id': 'uc5qQMzs96rzjK27epDCug',
#    'alias': 'joes-pizza-new-york-4',
#    'name': "Joe's Pizza",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FhbFkrh_3TrAOZvoWTyOJA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joes-pizza-new-york-4?adjust_creative=hkmQClvOY6h0M9H3Pd1pOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hkmQClvOY6h0M9H3Pd1pOg',
#    'review_count': 2204,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7305599, 'longitude': -74.0021299},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '7 Carmine St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7 Carmine St', 'New York, NY 10014']},
#    'phone': '+12123661182',
#    'display_phone': '(212) 366-1182',
#    'distance': 2873.5532231399425},
#   {'id': '2ggi1luerd3Mf_C82JvCYg',
#    'alias': 'grimaldis-opening-soon-brooklyn',
#    'name': "Grimaldi's - Opening Soon",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/kuYNC4RHDr724CkLek1MHQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grimaldis-opening-soon-brooklyn?adjust_creative=hkmQClvOY6h0M9H3Pd1pOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hkmQClvOY6h0M9H3Pd1pOg',
#    'review_count': 4453,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.70257, 'longitude': -73.99323},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1 Front St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1 Front St', 'Brooklyn, NY 11201']},
#    'phone': '+17188584300',
#    'display_phone': '(718) 858-4300',
#    'distance': 327.45636528596714},
#   {'id': 'C8j0q4Ma_S5hBGuAI-aaww',
#    'alias': 'di-fara-pizza-brooklyn',
#    'name': 'Di Fara Pizza',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4dfe9qpe20P-vi3qFjWd4Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/di-fara-pizza-brooklyn?adjust_creative=hkmQClvOY6h0M9H3Pd1pOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hkmQClvOY6h0M9H3Pd1pOg',
#    'review_count': 3212,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.625093, 'longitude': -73.961531},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1424 Ave J',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11230',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1424 Ave J', 'Brooklyn, NY 11230']},
#    'phone': '+17182581367',
#    'display_phone': '(718) 258-1367',
#    'distance': 9352.269072867253},
#   {'id': 'yH6t1JWcwkdWG4CS5KPvow',
#    'alias': 'adriennes-pizzabar-new-york',
#    'name': "Adrienne's Pizzabar",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/MOG8wpqkeYQxDslq7ospLw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/adriennes-pizzabar-new-york?adjust_creative=hkmQClvOY6h0M9H3Pd1pOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hkmQClvOY6h0M9H3Pd1pOg',
#    'review_count': 1517,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7043362, 'longitude': -74.0101733},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '54 Stone St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['54 Stone St', 'New York, NY 10004']},
#    'phone': '+12122483838',
#    'display_phone': '(212) 248-3838',
#    'distance': 1344.2671600758972},
#   {'id': 'oJ_XSPZFpvIt6rvheSQl7A',
#    'alias': 'bleecker-street-pizza-new-york',
#    'name': 'Bleecker Street Pizza',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Kyi2tP43S_a6s-zXD38NUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bleecker-street-pizza-new-york?adjust_creative=hkmQClvOY6h0M9H3Pd1pOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hkmQClvOY6h0M9H3Pd1pOg',
#    'review_count': 2006,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7320627016512,
#     'longitude': -74.0036552270137},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '69 7th Ave S',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['69 7th Ave S', 'New York, NY 10014']},
#    'phone': '+12129244466',
#    'display_phone': '(212) 924-4466',
#    'distance': 3072.9540450669765},
#   {'id': 'WG639VkTjmK5dzydd1BBJA',
#    'alias': 'rubirosa-new-york-2',
#    'name': 'Rubirosa',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LuSzR8cpVQRofXOT_bMi1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rubirosa-new-york-2?adjust_creative=hkmQClvOY6h0M9H3Pd1pOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hkmQClvOY6h0M9H3Pd1pOg',
#    'review_count': 1845,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72275, 'longitude': -73.99622},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '235 Mulberry St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['235 Mulberry St', 'New York, NY 10012']},
#    'phone': '+12129650500',
#    'display_phone': '(212) 965-0500',
#    'distance': 1931.2683716470422},
#   {'id': 'LF1QAuvpfX7KGQlg2zMg6Q',
#    'alias': 'johns-of-bleecker-street-new-york-2',
#    'name': "John's of Bleecker Street",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ey_5ReYpouWm4SlY2DsaVQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/johns-of-bleecker-street-new-york-2?adjust_creative=hkmQClvOY6h0M9H3Pd1pOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hkmQClvOY6h0M9H3Pd1pOg',
#    'review_count': 1756,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73158, 'longitude': -74.00332},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '278 Bleecker St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['278 Bleecker St', 'New York, NY 10014']},
#    'phone': '+12122431680',
#    'display_phone': '(212) 243-1680',
#    'distance': 3010.899021476809},
#   {'id': '-9NO2IDCJMyNGZMAQ1-VQw',
#    'alias': 'ny-pizza-suprema-new-york',
#    'name': 'NY Pizza Suprema',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/EqbDXneMuQP6pw6GemVdQA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ny-pizza-suprema-new-york?adjust_creative=hkmQClvOY6h0M9H3Pd1pOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hkmQClvOY6h0M9H3Pd1pOg',
#    'review_count': 1732,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7502059936523,
#     'longitude': -73.9953231811523},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '413 8th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['413 8th Ave', 'New York, NY 10001']},
#    'phone': '+12125948939',
#    'display_phone': '(212) 594-8939',
#    'distance': 4977.847939164096},
#   {'id': 'oRdM7n-AfBPBGAlH4Q0Sag',
#    'alias': 'my-pie-pizzeria-romana-new-york-2',
#    'name': 'My Pie Pizzeria Romana',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vo36uaolTTa5aREAcddJnw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/my-pie-pizzeria-romana-new-york-2?adjust_creative=hkmQClvOY6h0M9H3Pd1pOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hkmQClvOY6h0M9H3Pd1pOg',
#    'review_count': 634,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7608512, 'longitude': -73.9694809},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '690 Lexington Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['690 Lexington Ave', 'New York, NY 10022']},
#    'phone': '+12123171850',
#    'display_phone': '(212) 317-1850',
#    'distance': 6505.9564779774955},
#   {'id': 'FhXjAc6nKLf414KxYujUHw',
#    'alias': 'robertas-brooklyn-2',
#    'name': "Roberta's",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/xRNPKIfF2Gr02zBiBl3dSA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/robertas-brooklyn-2?adjust_creative=hkmQClvOY6h0M9H3Pd1pOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hkmQClvOY6h0M9H3Pd1pOg',
#    'review_count': 2617,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.705043534338, 'longitude': -73.93357123374},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '261 Moore St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['261 Moore St', 'Brooklyn, NY 11206']},
#    'phone': '+17184171118',
#    'display_phone': '(718) 417-1118',
#    'distance': 5118.690592147886},
#   {'id': 'vyoA8dxwScuMV_AsTcjQcg',
#    'alias': 'l-and-b-spumoni-gardens-brooklyn',
#    'name': 'L & B Spumoni Gardens',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BrTci9PjIwi7V1vkbgkdqg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-and-b-spumoni-gardens-brooklyn?adjust_creative=hkmQClvOY6h0M9H3Pd1pOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hkmQClvOY6h0M9H3Pd1pOg',
#    'review_count': 3372,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.594715, 'longitude': -73.981316},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '2725 86th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11223',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2725 86th St', 'Brooklyn, NY 11223']},
#    'phone': '+17184491230',
#    'display_phone': '(718) 449-1230',
#    'distance': 12361.163422806636},
#   {'id': 'i_rg-OLXQbpRUN7O3MeCeA',
#    'alias': 'piz-zetta-brooklyn-2',
#    'name': 'Piz-zetta',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9L4viDwAGx3obgYLnXMA6g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/piz-zetta-brooklyn-2?adjust_creative=hkmQClvOY6h0M9H3Pd1pOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hkmQClvOY6h0M9H3Pd1pOg',
#    'review_count': 240,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6912834070746,
#     'longitude': -73.9906029201042},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '90 Livingston St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['90 Livingston St', 'Brooklyn, NY 11201']},
#    'phone': '+17184227878',
#    'display_phone': '(718) 422-7878',
#    'distance': 1605.1176697811002},
#   {'id': 'vfYhEpp0x-DrNjC6GSJjPQ',
#    'alias': 'artichoke-basilles-pizza-new-york-2',
#    'name': "Artichoke Basille's Pizza",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/53JHO_-CRJ_e43JJIuN_Og/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/artichoke-basilles-pizza-new-york-2?adjust_creative=hkmQClvOY6h0M9H3Pd1pOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hkmQClvOY6h0M9H3Pd1pOg',
#    'review_count': 3774,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7321124557704,
#     'longitude': -73.9839056828882},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '321 E 14th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['321 E 14th St', 'New York, NY 10003']},
#    'phone': '+12122282004',
#    'display_phone': '(212) 228-2004',
#    'distance': 3091.822113723405},
#   {'id': 'c3D2ckzacnPtdGIM8tb-_w',
#    'alias': 'b-side-pizza-and-wine-bar-new-york',
#    'name': 'B Side Pizza & Wine Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/m_5goJPoabzTHCyQ2qAVGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/b-side-pizza-and-wine-bar-new-york?adjust_creative=hkmQClvOY6h0M9H3Pd1pOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hkmQClvOY6h0M9H3Pd1pOg',
#    'review_count': 978,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76394, 'longitude': -73.9883399},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '370 W 51st St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['370 W 51st St', 'New York, NY 10019']},
#    'phone': '+16466797225',
#    'display_phone': '(646) 679-7225',
#    'distance': 6519.850090048231},
#   {'id': '0UdC0VYX6aAvLiOcpR4MVQ',
#    'alias': 'joes-pizza-new-york-7',
#    'name': "Joe's Pizza",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9E2Um0ddicKyoWS-RGIXyg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joes-pizza-new-york-7?adjust_creative=hkmQClvOY6h0M9H3Pd1pOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hkmQClvOY6h0M9H3Pd1pOg',
#    'review_count': 756,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.733692, 'longitude': -73.988123},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '150 E 14th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['150 E 14th St', 'New York, NY 10003']},
#    'phone': '+12123889474',
#    'display_phone': '(212) 388-9474',
#    'distance': 3183.688184836435},
#   {'id': 'xrgzB0pvsxeGEIboE6I2gg',
#    'alias': 'patsys-pizzeria-brooklyn-2',
#    'name': "Patsy's Pizzeria",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1n5xL5ojLR-_zseirQKaMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/patsys-pizzeria-brooklyn-2?adjust_creative=hkmQClvOY6h0M9H3Pd1pOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hkmQClvOY6h0M9H3Pd1pOg',
#    'review_count': 457,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6818695, 'longitude': -73.976181},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '450 Dean St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['450 Dean St', 'Brooklyn, NY 11217']},
#    'phone': '+17186222268',
#    'display_phone': '(718) 622-2268',
#    'distance': 3034.9893998767334},
#   {'id': 'KEEXuHCYhsQJ-zpJhu98bA',
#    'alias': 'joes-pizza-new-york-148',
#    'name': "Joe's Pizza",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/5P5i2QZhxCen55PNdU_TTg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joes-pizza-new-york-148?adjust_creative=hkmQClvOY6h0M9H3Pd1pOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hkmQClvOY6h0M9H3Pd1pOg',
#    'review_count': 541,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7545841255557,
#     'longitude': -73.9870039190341},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '1435 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1435 Broadway', 'New York, NY 10018']},
#    'phone': '+16465594878',
#    'display_phone': '(646) 559-4878',
#    'distance': 5498.444221355099},
#   {'id': '2xQmBB6w-W6lxiex80fA9A',
#    'alias': 'luigis-pizzeria-brooklyn-4',
#    'name': "Luigi's Pizzeria",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QgrEW-SMfez8OkMHlgg-Rw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/luigis-pizzeria-brooklyn-4?adjust_creative=hkmQClvOY6h0M9H3Pd1pOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hkmQClvOY6h0M9H3Pd1pOg',
#    'review_count': 228,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6897, 'longitude': -73.965369},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '326 Dekalb Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['326 Dekalb Ave', 'Brooklyn, NY 11205']},
#    'phone': '+17187832430',
#    'display_phone': '(718) 783-2430',
#    'distance': 3001.8318150390764},
#   {'id': 'B1XdGwZZ5ee2fBdngj7NUw',
#    'alias': 'underground-pizza-new-york',
#    'name': 'Underground Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gCOE3o5WufGPCaJcin5nNg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/underground-pizza-new-york?adjust_creative=hkmQClvOY6h0M9H3Pd1pOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hkmQClvOY6h0M9H3Pd1pOg',
#    'review_count': 262,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70499, 'longitude': -74.00961},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '3 Hanover Sq',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3 Hanover Sq', 'New York, NY 10004']},
#    'phone': '+12124254442',
#    'display_phone': '(212) 425-4442',
#    'distance': 1295.7652741508907},
#   {'id': 'xxgcU_oFIox_pAmroo9WwA',
#    'alias': 'front-street-pizza-brooklyn',
#    'name': 'Front Street Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/3gefrnHNBSjOoa3PKvag9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/front-street-pizza-brooklyn?adjust_creative=hkmQClvOY6h0M9H3Pd1pOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hkmQClvOY6h0M9H3Pd1pOg',
#    'review_count': 291,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70244, 'longitude': -73.98943},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '80 Front St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['80 Front St', 'Brooklyn, NY 11201']},
#    'phone': '+17188753700',
#    'display_phone': '(718) 875-3700',
#    'distance': 530.2856895611},
#   {'id': 'atbANdSznV29GI066I2Ijw',
#    'alias': 'champion-pizza-new-york-6',
#    'name': 'Champion Pizza',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/SV5N-uxEa1tHUXYLAi43xA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/champion-pizza-new-york-6?adjust_creative=hkmQClvOY6h0M9H3Pd1pOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hkmQClvOY6h0M9H3Pd1pOg',
#    'review_count': 244,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7215270996094,
#     'longitude': -73.9970855712891},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '17 Cleveland Pl',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['17 Cleveland Pl', 'New York, NY 10012']},
#    'phone': '+12122263777',
#    'display_phone': '(212) 226-3777',
#    'distance': 1801.4764439408825},
#   {'id': 'kVrTff8uDMSBAaceBwQ7dg',
#    'alias': 'saluggis-new-york',
#    'name': "Saluggi's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/P_NI4AhmWBAi4c33PViGMg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/saluggis-new-york?adjust_creative=hkmQClvOY6h0M9H3Pd1pOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hkmQClvOY6h0M9H3Pd1pOg',
#    'review_count': 541,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.720104, 'longitude': -74.003578},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '325 Church St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['325 Church St', 'New York, NY 10013']},
#    'phone': '+12122267900',
#    'display_phone': '(212) 226-7900',
#    'distance': 1808.5885826304711},
#   {'id': 'GRXvvB1OKMuW4XDWEaVAlg',
#    'alias': 'joes-pizza-brooklyn-8',
#    'name': "Joe's Pizza",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zFqYcj13GBxvXQ4oRUGgsw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joes-pizza-brooklyn-8?adjust_creative=hkmQClvOY6h0M9H3Pd1pOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hkmQClvOY6h0M9H3Pd1pOg',
#    'review_count': 237,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71691, 'longitude': -73.958987},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '216 Bedford Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['216 Bedford Ave', 'Brooklyn, NY 11249']},
#    'phone': '+17183882216',
#    'display_phone': '(718) 388-2216',
#    'distance': 3239.2966565668607},
#   {'id': 'zmIrZgWhRdyRMrnEs9D3KA',
#    'alias': 'la-margarita-pizza-new-york',
#    'name': 'La Margarita Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7NH6z9iOZETlq8AKFwkcyQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-margarita-pizza-new-york?adjust_creative=hkmQClvOY6h0M9H3Pd1pOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hkmQClvOY6h0M9H3Pd1pOg',
#    'review_count': 259,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7215392420787,
#     'longitude': -73.9876275438289},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '168 Ludlow St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['168 Ludlow St', 'New York, NY 10002']},
#    'phone': '+19172614983',
#    'display_phone': '(917) 261-4983',
#    'distance': 1875.7222956933838},
#   {'id': 'FKzpfWUpyupl4q74Jt8fTA',
#    'alias': 'don-antonio-new-york-3',
#    'name': 'Don Antonio',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Kwv16TeExWDWWLLbCNq7Cw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/don-antonio-new-york-3?adjust_creative=hkmQClvOY6h0M9H3Pd1pOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hkmQClvOY6h0M9H3Pd1pOg',
#    'review_count': 1293,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.762711, 'longitude': -73.986708},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '309 W 50th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['309 W 50th St', 'New York, NY 10019']},
#    'phone': '+16467191043',
#    'display_phone': '(646) 719-1043',
#    'distance': 6399.689323736132},
#   {'id': 'S4uozcDEieoaXxIJ6TsUoQ',
#    'alias': 'dellaroccos-brick-oven-pizza-brooklyn',
#    'name': "Dellarocco's Brick Oven Pizza",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RGsip2vQXryVUbOrXfYBkQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dellaroccos-brick-oven-pizza-brooklyn?adjust_creative=hkmQClvOY6h0M9H3Pd1pOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hkmQClvOY6h0M9H3Pd1pOg',
#    'review_count': 231,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6950309, 'longitude': -73.9961252},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '214 Hicks St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['214 Hicks St', 'Brooklyn, NY 11201']},
#    'phone': '+17188581010',
#    'display_phone': '(718) 858-1010',
#    'distance': 1170.2700329972115},
#   {'id': 'eVk4F9ixl89zyUHJ1G2Aiw',
#    'alias': 'luzzos-la-pizza-napoletana-new-york-10',
#    'name': 'Luzzos La Pizza Napoletana',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CH1cvJ6DZD5v6agS9pgkAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/luzzos-la-pizza-napoletana-new-york-10?adjust_creative=hkmQClvOY6h0M9H3Pd1pOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hkmQClvOY6h0M9H3Pd1pOg',
#    'review_count': 1009,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.730551, 'longitude': -73.9834846},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '211 1st Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['211 1st Ave', 'New York, NY 10003']},
#    'phone': '+12124737447',
#    'display_phone': '(212) 473-7447',
#    'distance': 2936.5316530282876},
#   {'id': 'MeQU-nGaQvX12VXYOyzavQ',
#    'alias': 'gruppo-new-york-4',
#    'name': 'Gruppo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/O7OTQ9v4Zil2-oykg9NI8Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gruppo-new-york-4?adjust_creative=hkmQClvOY6h0M9H3Pd1pOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hkmQClvOY6h0M9H3Pd1pOg',
#    'review_count': 237,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72474, 'longitude': -73.98161},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '98 Ave B',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['98 Ave B', 'New York, NY 10009']},
#    'phone': '+12129952100',
#    'display_phone': '(212) 995-2100',
#    'distance': 2395.292393078858},
#   {'id': 'hGksyTiHBBdrhbiVjXzWVw',
#    'alias': 'scarrs-pizza-new-york',
#    'name': "Scarr's Pizza",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/tnaxDBYQfnuKIM1Sy1I8fg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/scarrs-pizza-new-york?adjust_creative=hkmQClvOY6h0M9H3Pd1pOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hkmQClvOY6h0M9H3Pd1pOg',
#    'review_count': 211,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71534, 'longitude': -73.9914},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '22 Orchard St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['22 Orchard St', 'New York, NY 10002']},
#    'phone': '+12123343481',
#    'display_phone': '(212) 334-3481',
#    'distance': 1125.7843300426755},
#   {'id': 'lxPVSGnZ7YTiO5OGrqBS8Q',
#    'alias': 'vinnies-pizzeria-brooklyn',
#    'name': "Vinnie's Pizzeria",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/T35Yd0xRbxwjaFJJ-CjiBQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vinnies-pizzeria-brooklyn?adjust_creative=hkmQClvOY6h0M9H3Pd1pOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hkmQClvOY6h0M9H3Pd1pOg',
#    'review_count': 612,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.718925, 'longitude': -73.956878},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '148 Bedford Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['148 Bedford Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17187827078',
#    'display_phone': '(718) 782-7078',
#    'distance': 3489.0079917146263},
#   {'id': 'QfCbV1_VIjfCkowro_WGNA',
#    'alias': 'luigis-pizza-brooklyn',
#    'name': "Luigi's Pizza",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/13Sy-QKtFjMBIJjXmayJDw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/luigis-pizza-brooklyn?adjust_creative=hkmQClvOY6h0M9H3Pd1pOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hkmQClvOY6h0M9H3Pd1pOg',
#    'review_count': 314,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.66163, 'longitude': -73.99334},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '686 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['686 5th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+17184993857',
#    'display_phone': '(718) 499-3857',
#    'distance': 4871.026714671667},
#   {'id': 'tRIHhPKryUZ56SfIz6mLiA',
#    'alias': 'angelos-coal-oven-pizzeria-new-york',
#    'name': "Angelo's Coal Oven Pizzeria",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WEMF90KApCuzyx1w8WnhdQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/angelos-coal-oven-pizzeria-new-york?adjust_creative=hkmQClvOY6h0M9H3Pd1pOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hkmQClvOY6h0M9H3Pd1pOg',
#    'review_count': 754,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76492, 'longitude': -73.97794},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '117 W 57th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['117 W 57th St', 'New York, NY 10019']},
#    'phone': '+12123334333',
#    'display_phone': '(212) 333-4333',
#    'distance': 6753.601098536139},
#   {'id': '1uOB_tWZwvI0_HakXfu5Jg',
#    'alias': 'nicks-pizza-new-york',
#    'name': "Nick's Pizza",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/B7wgdiOEVw6yU4RWbAEKyA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nicks-pizza-new-york?adjust_creative=hkmQClvOY6h0M9H3Pd1pOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hkmQClvOY6h0M9H3Pd1pOg',
#    'review_count': 489,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.78272, 'longitude': -73.94781},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1814 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10128',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1814 2nd Ave', 'New York, NY 10128']},
#    'phone': '+12129875700',
#    'display_phone': '(212) 987-5700',
#    'distance': 9442.562366002065},
#   {'id': '3VJwpmmeoPlCN3J5p5miEQ',
#    'alias': 'brooklyns-homeslice-pizzeria-brooklyn',
#    'name': "Brooklyn's Homeslice Pizzeria",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9ImrGJAQShKpXYR3XHor9Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brooklyns-homeslice-pizzeria-brooklyn?adjust_creative=hkmQClvOY6h0M9H3Pd1pOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hkmQClvOY6h0M9H3Pd1pOg',
#    'review_count': 94,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.680702, 'longitude': -73.967455},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '567 Vanderbilt Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['567 Vanderbilt Ave', 'Brooklyn, NY 11238']},
#    'phone': '+17183999000',
#    'display_phone': '(718) 399-9000',
#    'distance': 3562.2182094944847},
#   {'id': 'wTNUUoYUl3gox-gUAZ9bAA',
#    'alias': 'peppinos-brick-oven-pizza-and-restaurant-brooklyn-2',
#    'name': "Peppino's Brick Oven Pizza & Restaurant",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PCmB_Hk-usk05-PUXJvSqA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/peppinos-brick-oven-pizza-and-restaurant-brooklyn-2?adjust_creative=hkmQClvOY6h0M9H3Pd1pOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hkmQClvOY6h0M9H3Pd1pOg',
#    'review_count': 383,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.668221, 'longitude': -73.986936},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '469 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['469 5th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+17187687244',
#    'display_phone': '(718) 768-7244',
#    'distance': 4185.328288702886},
#   {'id': 'SpyQHasbnU5YkOR6PI4sNQ',
#    'alias': 'margherita-nyc-new-york',
#    'name': 'Margherita NYC',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GOUXE4GPpJ-yDw3CQcSysg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/margherita-nyc-new-york?adjust_creative=hkmQClvOY6h0M9H3Pd1pOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hkmQClvOY6h0M9H3Pd1pOg',
#    'review_count': 269,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7189865112305,
#     'longitude': -73.9969329833984},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '197 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['197 Grand St', 'New York, NY 10013']},
#    'phone': '+12122268391',
#    'display_phone': '(212) 226-8391',
#    'distance': 1531.530627996726},
#   {'id': 'Kh0-HmlgmVUkRxR55_Vn1g',
#    'alias': 'patsys-pizzeria-new-york-7',
#    'name': "Patsy's Pizzeria",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hx0TGZYLGItMgrZ6JFW6Xg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/patsys-pizzeria-new-york-7?adjust_creative=hkmQClvOY6h0M9H3Pd1pOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hkmQClvOY6h0M9H3Pd1pOg',
#    'review_count': 761,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.79713, 'longitude': -73.93481},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2287 1st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10035',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2287 1st Ave', 'New York, NY 10035']},
#    'phone': '+12125349783',
#    'display_phone': '(212) 534-9783',
#    'distance': 11359.622673182917},
#   {'id': 'YuzOnNDfRKixNJiaVy5Baw',
#    'alias': 'robertas-pizza-new-york-2',
#    'name': "Roberta's Pizza",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/DfRh3ueUr2FONIMGoitPMQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/robertas-pizza-new-york-2?adjust_creative=hkmQClvOY6h0M9H3Pd1pOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hkmQClvOY6h0M9H3Pd1pOg',
#    'review_count': 177,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7545170712701,
#     'longitude': -73.9765970005763},
#    'transactions': ['pickup'],
#    'price': '$$',
#    'location': {'address1': '230 Park Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10169',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['230 Park Ave', 'New York, NY 10169']},
#    'phone': '+16467470820',
#    'display_phone': '(646) 747-0820',
#    'distance': 5656.648409458703},
#   {'id': 'd7Asc4q2ImoPlA_BhfroTQ',
#    'alias': 'kesté-pizza-and-vino-new-york-2',
#    'name': 'Kesté Pizza & Vino',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QmCGZCd9KsysWQddAnHTdg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kest%C3%A9-pizza-and-vino-new-york-2?adjust_creative=hkmQClvOY6h0M9H3Pd1pOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hkmQClvOY6h0M9H3Pd1pOg',
#    'review_count': 1333,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73154, 'longitude': -74.00293},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '271 Bleecker St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['271 Bleecker St', 'New York, NY 10014']},
#    'phone': '+12122431500',
#    'display_phone': '(212) 243-1500',
#    'distance': 2991.8818535500936},
#   {'id': 'J38XGzriEkMsDfCMt6et_g',
#    'alias': 'vezzo-new-york-2',
#    'name': 'Vezzo',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/zEbvF-vMabMmovicwAoCSA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vezzo-new-york-2?adjust_creative=hkmQClvOY6h0M9H3Pd1pOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hkmQClvOY6h0M9H3Pd1pOg',
#    'review_count': 1179,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'pastashops', 'title': 'Pasta Shops'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7445, 'longitude': -73.98139},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '178 Lexington Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['178 Lexington Ave', 'New York, NY 10016']},
#    'phone': '+12128398300',
#    'display_phone': '(212) 839-8300',
#    'distance': 4477.207399502018},
#   {'id': 'MwcRbM6lS6_8N67LmyBELA',
#    'alias': '99-cent-fresh-pizza-new-york-5',
#    'name': '99 Cent Fresh Pizza',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/yy7ZIhBQiVIsoBINay-MIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/99-cent-fresh-pizza-new-york-5?adjust_creative=hkmQClvOY6h0M9H3Pd1pOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hkmQClvOY6h0M9H3Pd1pOg',
#    'review_count': 416,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76458, 'longitude': -73.98247},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1723 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1723 Broadway', 'New York, NY 10019']},
#    'phone': '+12122452155',
#    'display_phone': '(212) 245-2155',
#    'distance': 6652.683137648691},
#   {'id': 'uEKiv6WEPg9dWj10HCur5A',
#    'alias': 'table-87-coal-oven-pizza-brooklyn-5',
#    'name': 'Table 87 Coal Oven Pizza',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/P-SRieRAoqpG_o43B8TY8Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/table-87-coal-oven-pizza-brooklyn-5?adjust_creative=hkmQClvOY6h0M9H3Pd1pOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hkmQClvOY6h0M9H3Pd1pOg',
#    'review_count': 233,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.691219329834,
#     'longitude': -73.9973449707031},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '87 Atlantic Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['87 Atlantic Ave', 'Brooklyn, NY 11201']},
#    'phone': '+17187979300',
#    'display_phone': '(718) 797-9300',
#    'distance': 1602.5908124268826},
#   {'id': 'WE_dce2JKcv-VoFNaqiJ4w',
#    'alias': 'carmines-pizzeria-brooklyn',
#    'name': "Carmine's Pizzeria",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/NaB0yyTlKGBb4ivJo25XDg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/carmines-pizzeria-brooklyn?adjust_creative=hkmQClvOY6h0M9H3Pd1pOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hkmQClvOY6h0M9H3Pd1pOg',
#    'review_count': 406,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.714987, 'longitude': -73.94414},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '358 Graham Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['358 Graham Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17187829659',
#    'display_phone': '(718) 782-9659',
#    'distance': 4355.864983059872},
#   {'id': 'orvnuNWLuoE3-iEx4Aj8eA',
#    'alias': 'bakers-pizza-new-york',
#    'name': "Baker's Pizza",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/3TbUAZcHe7PQ278pONEU0w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bakers-pizza-new-york?adjust_creative=hkmQClvOY6h0M9H3Pd1pOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hkmQClvOY6h0M9H3Pd1pOg',
#    'review_count': 175,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7294399, 'longitude': -73.98125},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '201 Avenue A',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['201 Avenue A', 'New York, NY 10009']},
#    'phone': '+12127777477',
#    'display_phone': '(212) 777-7477',
#    'distance': 2883.8861591779555},
#   {'id': 'xsQTIeq-WLkp4ParkTQpMQ',
#    'alias': 'pizzarte-new-york',
#    'name': 'PizzArte',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KG9Kbt1xrxsl_xm4qQrngQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pizzarte-new-york?adjust_creative=hkmQClvOY6h0M9H3Pd1pOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hkmQClvOY6h0M9H3Pd1pOg',
#    'review_count': 982,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7629335072372,
#     'longitude': -73.9776668697596},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '69 W 55th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['69 W 55th St', 'New York, NY 10019']},
#    'phone': '+12122473936',
#    'display_phone': '(212) 247-3936',
#    'distance': 6544.13958857817},
#   {'id': 'JFw_Zj4CFTJbTPKJdPQ_Gw',
#    'alias': 'freddie-and-peppers-new-york',
#    'name': "Freddie & Pepper's",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/llep60r8kE65uo1ZYwkXUw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/freddie-and-peppers-new-york?adjust_creative=hkmQClvOY6h0M9H3Pd1pOg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=hkmQClvOY6h0M9H3Pd1pOg',
#    'review_count': 423,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.779999, 'longitude': -73.980301},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '303 Amsterdam Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['303 Amsterdam Ave', 'New York, NY 10023']},
#    'phone': '+12127992378',
#    'display_phone': '(212) 799-2378',
#    'distance': 8373.421944862941}],
#  'total': 7400,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %% [markdown]
# The final important note is how some of the parameters have alternative formats. For example, limit is an integer and open_now is a boolean according to the documentation. Following these conventions is essential to receiving valid responses.

# %% [markdown]
# # Summary
#
# Congratulations! Not only have you seen an API now, you've also practiced sifting through the documentation. The last piece in working with APIs is developing a more solid understanding of JSON files; the data format typically returned by modern APIs. Take some additional time and familarize yourself with some further aspects of the documentation which you may wish to investigate in the upcoming lab!
